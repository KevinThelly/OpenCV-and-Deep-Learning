# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic=Image.open('DATA/00-puppy.jpg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr= np.asarray(pic)

# %%
pic_arr.shape
#first two columns are the size of the matrix
#last one refers to the 3 channels (RGB)
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red =pic_arr.copy()

# %%
pic_red.shape
# Out:
# (1300, 1950, 3)

# %%
#R G B
#RED Channel values 0n ored -255 fullred
plt.imshow(pic_red[:,:,0])

# %%
plt.imshow(pic_red[:,:,0],cmap='gray')

# %%
#green
plt.imshow(pic_red[:,:,1],cmap='gray')

# %%
#blue
plt.imshow(pic_red[:,:,2],cmap='gray')

# %%
#removing green channel completely
pic_red[:,:,1]=0
plt.imshow(pic_red)

# %%
#removing blue channel completely
pic_red[:,:,2]=0
plt.imshow(pic_red)
